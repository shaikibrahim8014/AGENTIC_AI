# %% [markdown]
# Task:--A simple Q & A chatbot

# %%
pip install google-genai

# %%
import os
from google import genai

os.environ["GEMINI_API_KEY"] = "AQ.Ab8RN6LR98GwWh4Pm3o8h1zTB-4omnEcMCDN9M1Fk0xP8-f6Nw"

# Create client
client = genai.Client(api_key=os.environ["GEMINI_API_KEY"])
knowledge_base = """
KSRM College of Engineering is located in Kadapa.
The AIML department was established to teach Artificial Intelligence and Machine Learning.
Python is a popular programming language for ML.
Machine Learning uses data to learn patterns.
Deep Learning is a subset of Machine Learning."""

# Generate response

questions = """
What is Deep Learning?
What is Machine Learning?

"""


response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=f"""
Use only the following information to answer.

{knowledge_base}

Question: {question}
"""
)

print(response.text)
# Out:
# Deep Learning is a subset of Machine Learning.

# %% [markdown]
# LAB-Build a Study-Buddy Chatbot

# %%
# !pip install anthropic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 923.9/923.9 kB 14.2 MB/s eta 0:00:00
# ...

# %%
import anthropic
client = anthropic.Anthropic()
topic = input('What topic do you want to study today? ')
system_prompt = f'''You are a friendly, patient study buddy helping a student learn
about {topic}. Explain concepts simply, use examples, and ask a follow-up
question after each answer to check understanding. Keep answers
under 150 words.'''
conversation = [] # stores the full back-and-forth history
# Out:
# What topic do you want to study today? study buddy

# %%
print(f"Study buddy ready! Ask me anything about {topic}.")
print("Type 'quit' to exit.\n")
while True:
  user_input = input('You: ')
if user_input.lower() == 'quit':
  print('Good luck studying!')
  break
# Add the user's message to history
conversation.append({'role': 'user', 'content': user_input})
# Call the API with full history so the model remembers context
response = client.messages.create(
model='claude-sonnet-4-6',
max_tokens=400,
system=system_prompt,
messages=conversation
)
reply = response.content[0].text
print(f'Buddy: {reply}\n')
# Add the assistant's reply to history too — this is what gives
# the chatbot 'memory' within this session
conversation.append({'role': 'assistant', 'content': reply})
# Out:
# Study buddy ready! Ask me anything about study buddy.
# Type 'quit' to exit.
